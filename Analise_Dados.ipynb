# %% [markdown]
# <a href="https://colab.research.google.com/github/gds4/INF022-Analise-Dados/blob/main/Analise_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

#ideb_territorios-29-2023-AF.xlsx
#df = pd.read_excel('dados_aprendizado/saeb_aprendizado_territorios-29-2023-AF.xlsx', sheet_name='municipios')

#df.describe()

arquivos = [
    'dados_aprendizado/saeb_aprendizado_territorios-29-2023-AF.xlsx',
    'dados_aprendizado/saeb_aprendizado_territorios-29-2021-AF.xlsx',
    'dados_aprendizado/saeb_aprendizado_territorios-29-2019-AF.xlsx',
    'dados_aprendizado/saeb_aprendizado_territorios-29-2017-AF.xlsx',
    'dados_aprendizado/saeb_aprendizado_territorios-29-2015-AF.xlsx'
]


lista_df = []

for arquivo in arquivos:
    df_temp = pd.read_excel(arquivo, sheet_name='municipios')
    lista_df.append(df_temp)

df = pd.concat(lista_df, ignore_index=True)

df.groupby('ano')['lp_proficiente'].describe()
# Out:
#        count      mean       std   min       25%     50%       75%     max
# ano
# 2015   980.0  0.154075  0.070277  0.00  0.104275  0.1426  0.197425  0.5690
# 2017   932.0  0.174210  0.076832  0.00  0.114800  0.1688  0.218200  0.6458
# 2019  1208.0  0.148226  0.112645  0.00  0.000000  0.1618  0.226800  0.5950
# 2021  1179.0  0.196600  0.073084  0.00  0.143000  0.1919  0.236200  0.6154
# 2023   862.0  0.194394  0.076515  0.03  0.141500  0.1843  0.234500  0.5537
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['count'].plot(kind='hist', bins=20, title='count')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['mean'].plot(kind='hist', bins=20, title='mean')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
_df_14['std'].plot(kind='line', figsize=(8, 4), title='std')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_13['mean'].plot(kind='line', figsize=(8, 4), title='mean')
plt.gca().spines[['top', 'right']].set_visible(False)
